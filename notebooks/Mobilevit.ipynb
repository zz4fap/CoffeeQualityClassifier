# %% [markdown]
# # MobileViT: A mobile-friendly Transformer-based model for image classification
#
# **Author:** [Sayak Paul](https://twitter.com/RisingSayak)<br>
# **Date created:** 2021/10/20<br>
# **Last modified:** 2024/02/11<br>
# **Description:** MobileViT for image classification with combined benefits of convolutions and Transformers.

# %% [markdown]
# ## Introduction
#
# In this example, we implement the MobileViT architecture
# ([Mehta et al.](https://arxiv.org/abs/2110.02178)),
# which combines the benefits of Transformers
# ([Vaswani et al.](https://arxiv.org/abs/1706.03762))
# and convolutions. With Transformers, we can capture long-range dependencies that result
# in global representations. With convolutions, we can capture spatial relationships that
# model locality.
#
# Besides combining the properties of Transformers and convolutions, the authors introduce
# MobileViT as a general-purpose mobile-friendly backbone for different image recognition
# tasks. Their findings suggest that, performance-wise, MobileViT is better than other
# models with the same or higher complexity ([MobileNetV3](https://arxiv.org/abs/1905.02244),
# for example), while being efficient on mobile devices.
#
# Note: This example should be run with Tensorflow 2.13 and higher.

# %% [markdown]
# ## Imports

# %%
import os
import tensorflow as tf

from tensorflow import keras

# !pip install keras-nightly
# !pip install tensorflow

os.environ["KERAS_BACKEND"] = "tensorflow"

import keras
from keras import layers
from keras import backend

import tensorflow_datasets as tfds

tfds.disable_progress_bar()
# Out:
# Requirement already satisfied: keras-nightly in /usr/local/lib/python3.11/dist-packages (3.10.0.dev2025062603)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras-nightly) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras-nightly) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras-nightly) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras-nightly) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras-nightly) (3.14.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras-nightly) (0.16.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras-nightly) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras-nightly) (24.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras-nightly) (4.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras-nightly) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras-nightly) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras-nightly) (0.1.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.73.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %% [markdown]
# ## Hyperparameters

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = ('/content/drive/MyDrive/TypeCoffee.v25i.folder')
train_dir = os.path.join(data_dir, 'train')
validation_dir = os.path.join(data_dir, 'val')

# %%
# Values are from table 4.
patch_size = 4  # 2x2, for the Transformer blocks.
image_size = 256
expansion_factor = 2  # expansion factor for the MobileNetV2 blocks.

# %% [markdown]
# ## MobileViT utilities
#
# The MobileViT architecture is comprised of the following blocks:
#
# * Strided 3x3 convolutions that process the input image.
# * [MobileNetV2](https://arxiv.org/abs/1801.04381)-style inverted residual blocks for
# downsampling the resolution of the intermediate feature maps.
# * MobileViT blocks that combine the benefits of Transformers and convolutions. It is
# presented in the figure below (taken from the
# [original paper](https://arxiv.org/abs/2110.02178)):
#
#
# ![](https://i.imgur.com/mANnhI7.png)

# %%
def conv_block(x, filters=16, kernel_size=3, strides=2):
    conv_layer = layers.Conv2D(
        filters,
        kernel_size,
        strides=strides,
        activation=keras.activations.swish,
        padding="same",
    )
    return conv_layer(x)


# Reference: https://github.com/keras-team/keras/blob/e3858739d178fe16a0c77ce7fab88b0be6dbbdc7/keras/applications/imagenet_utils.py#L413C17-L435


def correct_pad(inputs, kernel_size):
    img_dim = 2 if backend.image_data_format() == "channels_first" else 1
    input_size = inputs.shape[img_dim : (img_dim + 2)]
    if isinstance(kernel_size, int):
        kernel_size = (kernel_size, kernel_size)
    if input_size[0] is None:
        adjust = (1, 1)
    else:
        adjust = (1 - input_size[0] % 2, 1 - input_size[1] % 2)
    correct = (kernel_size[0] // 2, kernel_size[1] // 2)
    return (
        (correct[0] - adjust[0], correct[0]),
        (correct[1] - adjust[1], correct[1]),
    )


# Reference: https://git.io/JKgtC


def inverted_residual_block(x, expanded_channels, output_channels, strides=1):
    m = layers.Conv2D(expanded_channels, 1, padding="same", use_bias=False)(x)
    m = layers.BatchNormalization()(m)
    m = keras.activations.swish(m)

    if strides == 2:
        m = layers.ZeroPadding2D(padding=correct_pad(m, 3))(m)
    m = layers.DepthwiseConv2D(
        3, strides=strides, padding="same" if strides == 1 else "valid", use_bias=False
    )(m)
    m = layers.BatchNormalization()(m)
    m = keras.activations.swish(m)

    m = layers.Conv2D(output_channels, 1, padding="same", use_bias=False)(m)
    m = layers.BatchNormalization()(m)

    if keras.ops.equal(x.shape[-1], output_channels) and strides == 1:
        return layers.Add()([m, x])
    return m


# Reference:
# https://keras.io/examples/vision/image_classification_with_vision_transformer/


def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=keras.activations.swish)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x


def transformer_block(x, transformer_layers, projection_dim, num_heads=2):
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(x)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, x])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(
            x3,
            hidden_units=[x.shape[-1] * 2, x.shape[-1]],
            dropout_rate=0.1,
        )
        # Skip connection 2.
        x = layers.Add()([x3, x2])

    return x


def mobilevit_block(x, num_blocks, projection_dim, strides=1):
    # Local projection with convolutions.
    local_features = conv_block(x, filters=projection_dim, strides=strides)
    local_features = conv_block(
        local_features, filters=projection_dim, kernel_size=1, strides=strides
    )

    # Unfold into patches and then pass through Transformers.
    num_patches = int((local_features.shape[1] * local_features.shape[2]) / patch_size)
    non_overlapping_patches = layers.Reshape((patch_size, num_patches, projection_dim))(
        local_features
    )
    global_features = transformer_block(
        non_overlapping_patches, num_blocks, projection_dim
    )

    # Fold into conv-like feature-maps.
    folded_feature_map = layers.Reshape((*local_features.shape[1:-1], projection_dim))(
        global_features
    )

    # Apply point-wise conv -> concatenate with the input features.
    folded_feature_map = conv_block(
        folded_feature_map, filters=x.shape[-1], kernel_size=1, strides=strides
    )
    local_global_features = layers.Concatenate(axis=-1)([x, folded_feature_map])

    # Fuse the local and global features using a convoluion layer.
    local_global_features = conv_block(
        local_global_features, filters=projection_dim, strides=strides
    )

    return local_global_features

# %% [markdown]
# **More on the MobileViT block**:
#
# * First, the feature representations (A) go through convolution blocks that capture local
# relationships. The expected shape of a single entry here would be `(h, w, num_channels)`.
# * Then they get unfolded into another vector with shape `(p, n, num_channels)`,
# where `p` is the area of a small patch, and `n` is `(h * w) / p`. So, we end up with `n`
# non-overlapping patches.
# * This unfolded vector is then passed through a Tranformer block that captures global
# relationships between the patches.
# * The output vector (B) is again folded into a vector of shape `(h, w, num_channels)`
# resembling a feature map coming out of convolutions.
#
# Vectors A and B are then passed through two more convolutional layers to fuse the local
# and global representations. Notice how the spatial resolution of the final vector remains
# unchanged at this point. The authors also present an explanation of how the MobileViT
# block resembles a convolution block of a CNN. For more details, please refer to the
# original paper.

# %% [markdown]
# Next, we combine these blocks together and implement the MobileViT architecture (XXS
# variant). The following figure (taken from the original paper) presents a schematic
# representation of the architecture:
#
# ![](https://i.ibb.co/sRbVRBN/image.png)

# %%
import keras
from tensorflow import keras
layers = keras.layers

def create_mobilevit(num_classes=5):
    inputs = keras.Input((image_size, image_size, 3))
    x = layers.Rescaling(scale=1.0 / 255)(inputs)

    # Initial conv-stem -> MV2 block.
    x = conv_block(x, filters=16)
    x = inverted_residual_block(
        x, expanded_channels=16 * expansion_factor, output_channels=16
    )

    # Downsampling with MV2 block.
    x = inverted_residual_block(
        x, expanded_channels=16 * expansion_factor, output_channels=24, strides=2
    )
    x = inverted_residual_block(
        x, expanded_channels=24 * expansion_factor, output_channels=24
    )
    x = inverted_residual_block(
        x, expanded_channels=24 * expansion_factor, output_channels=24
    )

    # First MV2 -> MobileViT block.
    x = inverted_residual_block(
        x, expanded_channels=24 * expansion_factor, output_channels=48, strides=2
    )
    x = mobilevit_block(x, num_blocks=2, projection_dim=64)

    # Second MV2 -> MobileViT block.
    x = inverted_residual_block(
        x, expanded_channels=64 * expansion_factor, output_channels=64, strides=2
    )
    x = mobilevit_block(x, num_blocks=4, projection_dim=80)

    # Third MV2 -> MobileViT block.
    x = inverted_residual_block(
        x, expanded_channels=80 * expansion_factor, output_channels=80, strides=2
    )
    x = mobilevit_block(x, num_blocks=3, projection_dim=96)
    x = conv_block(x, filters=320, kernel_size=1, strides=1)

    # Classification head.
    x = layers.GlobalAvgPool2D()(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return keras.Model(inputs, outputs)


mobilevit_xxs = create_mobilevit()
mobilevit_xxs.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 256, 256,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        448 │ rescaling[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │        512 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu (Silu)         │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (None, 128, 128,  │        288 │ silu[0][0]        │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_1 (Silu)       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │        512 │ silu_1[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │        512 │ add[0][0]         │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_2 (Silu)       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d      │ (None, 129, 129,  │          0 │ silu_2[0][0]      │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_1  │ (None, 64, 64,    │        288 │ zero_padding2d[0… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_3 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │        768 │ silu_3[0][0]      │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │      1,152 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_4 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_2  │ (None, 64, 64,    │        432 │ silu_4[0][0]      │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_5 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │      1,152 │ silu_5[0][0]      │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │      1,152 │ add_1[0][0]       │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_6 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_3  │ (None, 64, 64,    │        432 │ silu_6[0][0]      │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_7 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │      1,152 │ silu_7[0][0]      │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │      1,152 │ add_2[0][0]       │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_8 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1    │ (None, 65, 65,    │          0 │ silu_8[0][0]      │
# │ (ZeroPadding2D)     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4  │ (None, 32, 32,    │        432 │ zero_padding2d_1… │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_9 (Silu)       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │      2,304 │ silu_9[0][0]      │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │     27,712 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │      4,160 │ conv2d_11[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 4, 256,    │          0 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 4, 256,    │        128 │ reshape[0][0]     │
# │ (LayerNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 256,    │     33,216 │ layer_normalizat… │
# │ (MultiHeadAttentio… │ 64)               │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 4, 256,    │          0 │ multi_head_atten… │
# │                     │ 64)               │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 256,    │        128 │ add_3[0][0]       │
# │ (LayerNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 4, 256,    │      8,320 │ layer_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 4, 256,    │          0 │ dense[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 4, 256,    │      8,256 │ dropout_1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 4, 256,    │          0 │ dense_1[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 4, 256,    │          0 │ dropout_2[0][0],  │
# │                     │ 64)               │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 256,    │        128 │ add_4[0][0]       │
# │ (LayerNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 256,    │     33,216 │ layer_normalizat… │
# │ (MultiHeadAttentio… │ 64)               │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 4, 256,    │          0 │ multi_head_atten… │
# │                     │ 64)               │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 256,    │        128 │ add_5[0][0]       │
# │ (LayerNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4, 256,    │      8,320 │ layer_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 4, 256,    │          0 │ dense_2[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 4, 256,    │      8,256 │ dropout_4[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 4, 256,    │          0 │ dense_3[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 4, 256,    │          0 │ dropout_5[0][0],  │
# │                     │ 64)               │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 32, 32,    │          0 │ add_6[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │      3,120 │ reshape_1[0][0]   │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 96)               │            │ conv2d_13[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 32, 32,    │     55,360 │ concatenate[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 32, 32,    │      8,192 │ conv2d_14[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_10 (Silu)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_2    │ (None, 33, 33,    │          0 │ silu_10[0][0]     │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_5  │ (None, 16, 16,    │      1,152 │ zero_padding2d_2… │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_11 (Silu)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 16, 16,    │      8,192 │ silu_11[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 16, 16,    │     46,160 │ batch_normalizat… │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 16, 16,    │      6,480 │ conv2d_17[0][0]   │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 4, 64, 80) │          0 │ conv2d_18[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ reshape_2[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 64, 80) │     51,760 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 4, 64, 80) │          0 │ multi_head_atten… │
# │                     │                   │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 4, 64,     │     12,960 │ layer_normalizat… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 4, 64,     │          0 │ dense_4[0][0]     │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 4, 64, 80) │     12,880 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 4, 64, 80) │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 4, 64, 80) │          0 │ dropout_8[0][0],  │
# │                     │                   │            │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 64, 80) │     51,760 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 4, 64, 80) │          0 │ multi_head_atten… │
# │                     │                   │            │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 4, 64,     │     12,960 │ layer_normalizat… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 4, 64,     │          0 │ dense_6[0][0]     │
# │ (Dropout)           │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 4, 64, 80) │     12,880 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 4, 64, 80) │          0 │ dense_7[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 4, 64, 80) │          0 │ dropout_11[0][0], │
# │                     │                   │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 64, 80) │     51,760 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 4, 64, 80) │          0 │ multi_head_atten… │
# │                     │                   │            │ add_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_11[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 4, 64,     │     12,960 │ layer_normalizat… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 4, 64,     │          0 │ dense_8[0][0]     │
# │ (Dropout)           │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 4, 64, 80) │     12,880 │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 4, 64, 80) │          0 │ dense_9[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 4, 64, 80) │          0 │ dropout_14[0][0], │
# │                     │                   │            │ add_11[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 64, 80) │     51,760 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 4, 64, 80) │          0 │ multi_head_atten… │
# │                     │                   │            │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 4, 64,     │     12,960 │ layer_normalizat… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 4, 64,     │          0 │ dense_10[0][0]    │
# │ (Dropout)           │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 4, 64, 80) │     12,880 │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 4, 64, 80) │          0 │ dense_11[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 4, 64, 80) │          0 │ dropout_17[0][0], │
# │                     │                   │            │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 16, 16,    │          0 │ add_14[0][0]      │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 16, 16,    │      5,184 │ reshape_3[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 128)              │            │ conv2d_19[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 16, 16,    │     92,240 │ concatenate_1[0]… │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 16, 16,    │     12,800 │ conv2d_20[0][0]   │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        640 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_12 (Silu)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_3    │ (None, 17, 17,    │          0 │ silu_12[0][0]     │
# │ (ZeroPadding2D)     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_6  │ (None, 8, 8, 160) │      1,440 │ zero_padding2d_3… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 160) │        640 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_13 (Silu)      │ (None, 8, 8, 160) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 8, 8, 80)  │     12,800 │ silu_13[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 80)  │        320 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 8, 8, 96)  │     69,216 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 8, 8, 96)  │      9,312 │ conv2d_23[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, 4, 16, 96) │          0 │ conv2d_24[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ reshape_4[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 16, 96) │     74,400 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 4, 16, 96) │          0 │ multi_head_atten… │
# │                     │                   │            │ reshape_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ add_15[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 4, 16,     │     18,624 │ layer_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 4, 16,     │          0 │ dense_12[0][0]    │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 4, 16, 96) │     18,528 │ dropout_19[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 4, 16, 96) │          0 │ dense_13[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 4, 16, 96) │          0 │ dropout_20[0][0], │
# │                     │                   │            │ add_15[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ add_16[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 16, 96) │     74,400 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 4, 16, 96) │          0 │ multi_head_atten… │
# │                     │                   │            │ add_16[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ add_17[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 4, 16,     │     18,624 │ layer_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 4, 16,     │          0 │ dense_14[0][0]    │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 4, 16, 96) │     18,528 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 4, 16, 96) │          0 │ dense_15[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 4, 16, 96) │          0 │ dropout_23[0][0], │
# │                     │                   │            │ add_17[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ add_18[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 16, 96) │     74,400 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 4, 16, 96) │          0 │ multi_head_atten… │
# │                     │                   │            │ add_18[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ add_19[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 4, 16,     │     18,624 │ layer_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 4, 16,     │          0 │ dense_16[0][0]    │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 4, 16, 96) │     18,528 │ dropout_25[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 4, 16, 96) │          0 │ dense_17[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 4, 16, 96) │          0 │ dropout_26[0][0], │
# │                     │                   │            │ add_19[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_5 (Reshape) │ (None, 8, 8, 96)  │          0 │ add_20[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 8, 8, 80)  │      7,760 │ reshape_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 8, 8, 160) │          0 │ batch_normalizat… │
# │ (Concatenate)       │                   │            │ conv2d_25[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 8, 8, 96)  │    138,336 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 8, 8, 320) │     31,040 │ conv2d_26[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 320)       │          0 │ conv2d_27[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 5)         │      1,605 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,307,621 (4.99 MB)
#  Trainable params: 1,305,077 (4.98 MB)
#  Non-trainable params: 2,544 (9.94 KB)

# %% [markdown]
# ## Dataset preparation
#
# We will be using the
# [`tf_flowers`](https://www.tensorflow.org/datasets/catalog/tf_flowers)
# dataset to demonstrate the model. Unlike other Transformer-based architectures,
# MobileViT uses a simple augmentation pipeline primarily because it has the properties
# of a CNN.

# %%
batch_size = 32
auto = tf.data.AUTOTUNE
resize_bigger = 280
num_classes = 5


def preprocess_dataset(is_training=True):
    def _pp(image, label):
        if is_training:
            # Resize to a bigger spatial resolution and take the random
            # crops.
            image = tf.image.resize(image, (resize_bigger, resize_bigger))
            image = tf.image.random_crop(image, (image_size, image_size, 3))
            image = tf.image.random_flip_left_right(image)
        else:
            image = tf.image.resize(image, (image_size, image_size))
        label = tf.one_hot(label, depth=num_classes)
        return image, label

    return _pp


def prepare_dataset(dataset, is_training=True):
    if is_training:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.map(preprocess_dataset(is_training), num_parallel_calls=auto)
    return dataset.batch(batch_size).prefetch(auto)

# %% [markdown]
# The authors use a multi-scale data sampler to help the model learn representations of
# varied scales. In this example, we discard this part.

# %% [markdown]
# ## Load and prepare the dataset

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(train_dir,
                                                            shuffle=True,
                                                            batch_size=batch_size,
                                                            image_size=(256,256))

val_dataset = tf.keras.utils.image_dataset_from_directory(validation_dir,
                                                                 shuffle=True,
                                                                 batch_size=batch_size,
                                                                 image_size=(256,256))

test_dir = os.path.join(data_dir, 'test')
test_dataset = tf.keras.utils.image_dataset_from_directory(test_dir)
# Out:
# Found 1049 files belonging to 5 classes.
# Found 60 files belonging to 5 classes.
# Found 100 files belonging to 5 classes.

# %% [markdown]
# ## Train a MobileViT (XXS) model

# %%
learning_rate = 0.002
label_smoothing_factor = 0.1
epochs = 500

optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
#loss_fn = keras.losses.SparseCategoricalCrossentropy(label_smoothing=label_smoothing_factor)
loss_fn=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

def run_experiment(epochs=epochs):
    mobilevit_xxs = create_mobilevit(num_classes=num_classes)
    mobilevit_xxs.compile(optimizer=optimizer, loss=loss_fn, metrics=["accuracy"])

    # When using `save_weights_only=True` in `ModelCheckpoint`, the filepath provided must end in `.weights.h5`
    checkpoint_filepath = "/tmp/checkpoint.weights.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    mobilevit_xxs.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=epochs,
        callbacks=[checkpoint_callback],
    )
    mobilevit_xxs.load_weights(checkpoint_filepath)
    _, accuracy = mobilevit_xxs.evaluate(val_dataset)
    print(f"Validation accuracy: {round(accuracy * 100, 2)}%")
    return mobilevit_xxs


mobilevit_xxs = run_experiment()
# Out:
# Epoch 1/500
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/nn.py:717: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - accuracy: 0.3470 - loss: 1.4644 - val_accuracy: 0.2167 - val_loss: 1.6481
# Epoch 2/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 186ms/step - accuracy: 0.4623 - loss: 1.1529 - val_accuracy: 0.2167 - val_loss: 1.6488
# Epoch 3/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 186ms/step - accuracy: 0.5443 - loss: 0.9700 - val_accuracy: 0.2167 - val_loss: 1.9535
# Epoch 4/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 188ms/step - accuracy: 0.5920 - loss: 0.8531 - val_accuracy: 0.2167 - val_loss: 1.8352
# Epoch 5/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 188ms/step - accuracy: 0.6444 - loss: 0.7746 - val_accuracy: 0.1667 - val_loss: 2.0442
# Epoch 6/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.6835 - loss: 0.7036 - val_accuracy: 0.1833 - val_loss: 6.0285
# Epoch 7/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.7083 - loss: 0.6315 - val_accuracy: 0.1833 - val_loss: 4.2857
# Epoch 8/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.7855 - loss: 0.5424 - val_accuracy: 0.1833 - val_loss: 3.8449
# Epoch 9/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.7684 - loss: 0.5373 - val_accuracy: 0.1833 - val_loss: 12.1580
# Epoch 10/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.8379 - loss: 0.4124 - val_accuracy: 0.1833 - val_loss: 8.3015
# Epoch 11/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.8170 - loss: 0.4180 - val_accuracy: 0.1833 - val_loss: 7.6020
# Epoch 12/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.8808 - loss: 0.3172 - val_accuracy: 0.1833 - val_loss: 4.0570
# Epoch 13/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.8227 - loss: 0.4501 - val_accuracy: 0.1833 - val_loss: 10.6417
# Epoch 14/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9028 - loss: 0.2443 - val_accuracy: 0.1833 - val_loss: 23.7109
# Epoch 15/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - accuracy: 0.8980 - loss: 0.2659 - val_accuracy: 0.3333 - val_loss: 2.0813
# Epoch 16/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - accuracy: 0.8837 - loss: 0.2835 - val_accuracy: 0.4000 - val_loss: 12.3386
# Epoch 17/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.9466 - loss: 0.1483 - val_accuracy: 0.3333 - val_loss: 2.3656
# Epoch 18/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9390 - loss: 0.1681 - val_accuracy: 0.4000 - val_loss: 5.8900
# Epoch 19/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9380 - loss: 0.1757 - val_accuracy: 0.3833 - val_loss: 6.0790
# Epoch 20/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9323 - loss: 0.1724 - val_accuracy: 0.3000 - val_loss: 16.7390
# Epoch 21/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - accuracy: 0.9685 - loss: 0.0850 - val_accuracy: 0.6500 - val_loss: 1.1613
# Epoch 22/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9657 - loss: 0.1042 - val_accuracy: 0.2167 - val_loss: 28.3819
# Epoch 23/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9752 - loss: 0.0553 - val_accuracy: 0.4167 - val_loss: 6.1898
# Epoch 24/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9743 - loss: 0.0738 - val_accuracy: 0.4167 - val_loss: 7.6818
# Epoch 25/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - accuracy: 0.9819 - loss: 0.0509 - val_accuracy: 0.7500 - val_loss: 0.8961
# Epoch 26/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9657 - loss: 0.0916 - val_accuracy: 0.2167 - val_loss: 42.9587
# Epoch 27/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9199 - loss: 0.2745 - val_accuracy: 0.2167 - val_loss: 53.5763
# Epoch 28/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9733 - loss: 0.0797 - val_accuracy: 0.2667 - val_loss: 17.8834
# Epoch 29/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9838 - loss: 0.0419 - val_accuracy: 0.3833 - val_loss: 7.9836
# Epoch 30/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.9819 - loss: 0.0564 - val_accuracy: 0.4000 - val_loss: 9.9990
# Epoch 31/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9752 - loss: 0.0738 - val_accuracy: 0.6000 - val_loss: 4.2059
# Epoch 32/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9581 - loss: 0.1222 - val_accuracy: 0.2167 - val_loss: 28.1649
# Epoch 33/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9571 - loss: 0.1078 - val_accuracy: 0.3333 - val_loss: 22.4372
# Epoch 34/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9695 - loss: 0.0950 - val_accuracy: 0.6833 - val_loss: 1.7356
# Epoch 35/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9781 - loss: 0.0775 - val_accuracy: 0.2333 - val_loss: 9.8450
# Epoch 36/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9685 - loss: 0.0833 - val_accuracy: 0.3667 - val_loss: 10.6822
# Epoch 37/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9838 - loss: 0.0478 - val_accuracy: 0.6667 - val_loss: 1.2148
# Epoch 38/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9838 - loss: 0.0443 - val_accuracy: 0.5000 - val_loss: 3.6070
# Epoch 39/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9886 - loss: 0.0270 - val_accuracy: 0.5333 - val_loss: 7.1767
# Epoch 40/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9924 - loss: 0.0294 - val_accuracy: 0.1833 - val_loss: 38.9639
# Epoch 41/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.9819 - loss: 0.0515 - val_accuracy: 0.4000 - val_loss: 9.3489
# Epoch 42/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9638 - loss: 0.1139 - val_accuracy: 0.2000 - val_loss: 9.6048
# Epoch 43/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.9724 - loss: 0.0918 - val_accuracy: 0.4500 - val_loss: 13.6015
# Epoch 44/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9819 - loss: 0.0466 - val_accuracy: 0.6833 - val_loss: 3.5826
# Epoch 45/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9905 - loss: 0.0270 - val_accuracy: 0.4833 - val_loss: 10.2352
# Epoch 46/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9952 - loss: 0.0165 - val_accuracy: 0.5500 - val_loss: 6.0147
# Epoch 47/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9886 - loss: 0.0356 - val_accuracy: 0.4333 - val_loss: 7.1620
# Epoch 48/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9743 - loss: 0.0974 - val_accuracy: 0.4000 - val_loss: 9.0748
# Epoch 49/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9695 - loss: 0.1061 - val_accuracy: 0.3500 - val_loss: 16.3432
# Epoch 50/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9819 - loss: 0.0568 - val_accuracy: 0.2667 - val_loss: 12.8163
# Epoch 51/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9905 - loss: 0.0278 - val_accuracy: 0.5667 - val_loss: 5.7960
# Epoch 52/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0062 - val_accuracy: 0.6167 - val_loss: 3.6986
# Epoch 53/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9952 - loss: 0.0115 - val_accuracy: 0.7333 - val_loss: 1.8530
# Epoch 54/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9943 - loss: 0.0176 - val_accuracy: 0.4500 - val_loss: 7.9087
# Epoch 55/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9943 - loss: 0.0226 - val_accuracy: 0.4333 - val_loss: 8.8685
# Epoch 56/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9924 - loss: 0.0214 - val_accuracy: 0.7333 - val_loss: 2.3633
# Epoch 57/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9924 - loss: 0.0329 - val_accuracy: 0.5167 - val_loss: 6.6091
# Epoch 58/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9857 - loss: 0.0583 - val_accuracy: 0.5500 - val_loss: 6.3657
# Epoch 59/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9733 - loss: 0.0850 - val_accuracy: 0.5333 - val_loss: 5.9948
# Epoch 60/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9828 - loss: 0.0412 - val_accuracy: 0.5000 - val_loss: 9.3281
# Epoch 61/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9771 - loss: 0.0664 - val_accuracy: 0.5833 - val_loss: 4.6995
# Epoch 62/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9924 - loss: 0.0254 - val_accuracy: 0.4500 - val_loss: 10.2209
# Epoch 63/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9800 - loss: 0.0514 - val_accuracy: 0.5167 - val_loss: 2.8265
# Epoch 64/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.9666 - loss: 0.0947 - val_accuracy: 0.5333 - val_loss: 11.6492
# Epoch 65/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9714 - loss: 0.0813 - val_accuracy: 0.6667 - val_loss: 2.2607
# Epoch 66/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.9838 - loss: 0.0448 - val_accuracy: 0.5333 - val_loss: 2.4915
# Epoch 67/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.9647 - loss: 0.1033 - val_accuracy: 0.3500 - val_loss: 18.3825
# Epoch 68/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.9876 - loss: 0.0254 - val_accuracy: 0.5167 - val_loss: 3.6169
# Epoch 69/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9981 - loss: 0.0087 - val_accuracy: 0.7333 - val_loss: 1.6972
# Epoch 70/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9847 - loss: 0.0473 - val_accuracy: 0.4167 - val_loss: 6.3083
# Epoch 71/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9171 - loss: 0.2457 - val_accuracy: 0.2167 - val_loss: 39.2180
# Epoch 72/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9295 - loss: 0.2280 - val_accuracy: 0.5333 - val_loss: 10.0012
# Epoch 73/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.9256 - loss: 0.2156 - val_accuracy: 0.4333 - val_loss: 11.5731
# Epoch 74/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9561 - loss: 0.1156 - val_accuracy: 0.5333 - val_loss: 3.1284
# Epoch 75/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9724 - loss: 0.0757 - val_accuracy: 0.5333 - val_loss: 7.5709
# Epoch 76/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9905 - loss: 0.0322 - val_accuracy: 0.3833 - val_loss: 8.6341
# Epoch 77/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9876 - loss: 0.0348 - val_accuracy: 0.6833 - val_loss: 1.8844
# Epoch 78/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9933 - loss: 0.0245 - val_accuracy: 0.7000 - val_loss: 3.4376
# Epoch 79/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - accuracy: 0.9981 - loss: 0.0095 - val_accuracy: 0.8333 - val_loss: 0.6704
# Epoch 80/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0095 - val_accuracy: 0.7667 - val_loss: 1.4167
# Epoch 81/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9762 - loss: 0.0879 - val_accuracy: 0.3333 - val_loss: 8.0576
# Epoch 82/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9781 - loss: 0.0534 - val_accuracy: 0.4833 - val_loss: 12.3085
# Epoch 83/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9809 - loss: 0.0625 - val_accuracy: 0.5833 - val_loss: 3.1590
# Epoch 84/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9771 - loss: 0.0566 - val_accuracy: 0.5333 - val_loss: 7.1072
# Epoch 85/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9762 - loss: 0.0631 - val_accuracy: 0.5500 - val_loss: 7.3764
# Epoch 86/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9867 - loss: 0.0458 - val_accuracy: 0.4500 - val_loss: 9.5895
# Epoch 87/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9943 - loss: 0.0193 - val_accuracy: 0.4167 - val_loss: 11.6072
# Epoch 88/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9952 - loss: 0.0251 - val_accuracy: 0.6333 - val_loss: 3.4684
# Epoch 89/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9914 - loss: 0.0218 - val_accuracy: 0.6333 - val_loss: 1.8594
# Epoch 90/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - accuracy: 0.9990 - loss: 0.0088 - val_accuracy: 0.8833 - val_loss: 0.3584
# Epoch 91/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9905 - loss: 0.0256 - val_accuracy: 0.4167 - val_loss: 10.1976
# Epoch 92/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0045 - val_accuracy: 0.5833 - val_loss: 4.8905
# Epoch 93/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.8833 - val_loss: 0.3991
# Epoch 94/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9933 - loss: 0.0192 - val_accuracy: 0.1833 - val_loss: 32.5434
# Epoch 95/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9819 - loss: 0.0707 - val_accuracy: 0.7167 - val_loss: 4.9126
# Epoch 96/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9609 - loss: 0.1251 - val_accuracy: 0.4167 - val_loss: 25.2917
# Epoch 97/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9819 - loss: 0.0554 - val_accuracy: 0.3833 - val_loss: 19.5233
# Epoch 98/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9933 - loss: 0.0193 - val_accuracy: 0.1833 - val_loss: 79.5409
# Epoch 99/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9800 - loss: 0.0749 - val_accuracy: 0.2167 - val_loss: 29.2117
# Epoch 100/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9733 - loss: 0.0720 - val_accuracy: 0.4167 - val_loss: 17.9780
# Epoch 101/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9752 - loss: 0.0754 - val_accuracy: 0.2333 - val_loss: 59.3403
# Epoch 102/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9752 - loss: 0.0749 - val_accuracy: 0.5167 - val_loss: 4.3196
# Epoch 103/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9886 - loss: 0.0276 - val_accuracy: 0.5833 - val_loss: 3.5085
# Epoch 104/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0057 - val_accuracy: 0.7500 - val_loss: 0.7995
# Epoch 105/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9962 - loss: 0.0085 - val_accuracy: 0.7000 - val_loss: 3.6998
# Epoch 106/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0045 - val_accuracy: 0.8500 - val_loss: 0.6839
# Epoch 107/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9952 - loss: 0.0126 - val_accuracy: 0.8000 - val_loss: 1.8075
# Epoch 108/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9962 - loss: 0.0097 - val_accuracy: 0.5667 - val_loss: 7.1172
# Epoch 109/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9933 - loss: 0.0130 - val_accuracy: 0.7500 - val_loss: 2.5024
# Epoch 110/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9943 - loss: 0.0170 - val_accuracy: 0.8333 - val_loss: 0.4096
# Epoch 111/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0135 - val_accuracy: 0.7167 - val_loss: 2.8844
# Epoch 112/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.7000 - val_loss: 2.1386
# Epoch 113/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0024 - val_accuracy: 0.5167 - val_loss: 5.1242
# Epoch 114/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9962 - loss: 0.0201 - val_accuracy: 0.3167 - val_loss: 8.1215
# Epoch 115/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9962 - loss: 0.0083 - val_accuracy: 0.7500 - val_loss: 1.0250
# Epoch 116/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9943 - loss: 0.0169 - val_accuracy: 0.6333 - val_loss: 3.7367
# Epoch 117/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9971 - loss: 0.0064 - val_accuracy: 0.7833 - val_loss: 1.2765
# Epoch 118/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9895 - loss: 0.0263 - val_accuracy: 0.7667 - val_loss: 1.8464
# Epoch 119/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9743 - loss: 0.0870 - val_accuracy: 0.5167 - val_loss: 2.7678
# Epoch 120/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9704 - loss: 0.0800 - val_accuracy: 0.4000 - val_loss: 16.9302
# Epoch 121/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9905 - loss: 0.0209 - val_accuracy: 0.4833 - val_loss: 9.2079
# Epoch 122/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9943 - loss: 0.0158 - val_accuracy: 0.4333 - val_loss: 9.9919
# Epoch 123/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9962 - loss: 0.0153 - val_accuracy: 0.5000 - val_loss: 10.7686
# Epoch 124/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9857 - loss: 0.0351 - val_accuracy: 0.1833 - val_loss: 40.4714
# Epoch 125/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9952 - loss: 0.0119 - val_accuracy: 0.6000 - val_loss: 5.5571
# Epoch 126/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9962 - loss: 0.0146 - val_accuracy: 0.7167 - val_loss: 2.2051
# Epoch 127/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0024 - val_accuracy: 0.7167 - val_loss: 1.6993
# Epoch 128/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0058 - val_accuracy: 0.5833 - val_loss: 3.7674
# Epoch 129/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9962 - loss: 0.0117 - val_accuracy: 0.3833 - val_loss: 6.5069
# Epoch 130/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9962 - loss: 0.0108 - val_accuracy: 0.6333 - val_loss: 2.5218
# Epoch 131/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9971 - loss: 0.0081 - val_accuracy: 0.4500 - val_loss: 6.7766
# Epoch 132/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.5500 - val_loss: 5.1836
# Epoch 133/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 1.0000 - loss: 9.0032e-04 - val_accuracy: 0.6667 - val_loss: 2.7962
# Epoch 134/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8333 - val_loss: 1.2251
# Epoch 135/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.7667 - val_loss: 3.0374
# Epoch 136/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9971 - loss: 0.0104 - val_accuracy: 0.8833 - val_loss: 0.4933
# Epoch 137/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9838 - loss: 0.0664 - val_accuracy: 0.2167 - val_loss: 38.3081
# Epoch 138/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9781 - loss: 0.1095 - val_accuracy: 0.2167 - val_loss: 92.5792
# Epoch 139/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9838 - loss: 0.0504 - val_accuracy: 0.4000 - val_loss: 10.5437
# Epoch 140/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9828 - loss: 0.0473 - val_accuracy: 0.5333 - val_loss: 7.0195
# Epoch 141/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9943 - loss: 0.0151 - val_accuracy: 0.4333 - val_loss: 6.2281
# Epoch 142/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9952 - loss: 0.0114 - val_accuracy: 0.3500 - val_loss: 16.7580
# Epoch 143/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9933 - loss: 0.0120 - val_accuracy: 0.6167 - val_loss: 6.0564
# Epoch 144/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.7000 - val_loss: 2.1337
# Epoch 145/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 9.6260e-04 - val_accuracy: 0.7833 - val_loss: 1.1830
# Epoch 146/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9981 - loss: 0.0082 - val_accuracy: 0.7667 - val_loss: 2.9012
# Epoch 147/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0071 - val_accuracy: 0.8333 - val_loss: 1.6735
# Epoch 148/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9981 - loss: 0.0045 - val_accuracy: 0.6000 - val_loss: 6.0456
# Epoch 149/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0043 - val_accuracy: 0.7667 - val_loss: 2.5459
# Epoch 150/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9895 - loss: 0.0205 - val_accuracy: 0.5833 - val_loss: 4.9788
# Epoch 151/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9933 - loss: 0.0282 - val_accuracy: 0.5500 - val_loss: 6.5803
# Epoch 152/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9762 - loss: 0.0992 - val_accuracy: 0.4000 - val_loss: 5.7442
# Epoch 153/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9838 - loss: 0.0416 - val_accuracy: 0.6500 - val_loss: 4.2172
# Epoch 154/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9981 - loss: 0.0154 - val_accuracy: 0.5000 - val_loss: 6.6907
# Epoch 155/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9971 - loss: 0.0061 - val_accuracy: 0.8000 - val_loss: 1.4529
# Epoch 156/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.7333 - val_loss: 2.8443
# Epoch 157/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0033 - val_accuracy: 0.6833 - val_loss: 2.8174
# Epoch 158/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0014 - val_accuracy: 0.6000 - val_loss: 3.7979
# Epoch 159/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9962 - loss: 0.0158 - val_accuracy: 0.4833 - val_loss: 20.1582
# Epoch 160/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0044 - val_accuracy: 0.2833 - val_loss: 30.0404
# Epoch 161/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9952 - loss: 0.0121 - val_accuracy: 0.5667 - val_loss: 4.5804
# Epoch 162/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9828 - loss: 0.0620 - val_accuracy: 0.2333 - val_loss: 18.7446
# Epoch 163/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9590 - loss: 0.1405 - val_accuracy: 0.5333 - val_loss: 6.0005
# Epoch 164/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9895 - loss: 0.0356 - val_accuracy: 0.7000 - val_loss: 2.6760
# Epoch 165/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9981 - loss: 0.0097 - val_accuracy: 0.7667 - val_loss: 3.1455
# Epoch 166/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - accuracy: 0.9971 - loss: 0.0089 - val_accuracy: 0.9000 - val_loss: 0.6681
# Epoch 167/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9971 - loss: 0.0089 - val_accuracy: 0.7167 - val_loss: 2.6511
# Epoch 168/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9333 - val_loss: 0.3494
# Epoch 169/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0030 - val_accuracy: 0.3833 - val_loss: 39.1229
# Epoch 170/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0050 - val_accuracy: 0.5167 - val_loss: 16.5880
# Epoch 171/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0031 - val_accuracy: 0.2333 - val_loss: 26.5869
# Epoch 172/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.4833 - val_loss: 10.0258
# Epoch 173/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 1.5025e-04 - val_accuracy: 0.4500 - val_loss: 7.4041
# Epoch 174/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.4000 - val_loss: 8.0221
# Epoch 175/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 2.2051e-04 - val_accuracy: 0.5333 - val_loss: 5.2340
# Epoch 176/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 2.8036e-04 - val_accuracy: 0.6667 - val_loss: 2.6613
# Epoch 177/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 0.5500 - val_loss: 7.6491
# Epoch 178/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9962 - loss: 0.0091 - val_accuracy: 0.3833 - val_loss: 23.6303
# Epoch 179/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9828 - loss: 0.0541 - val_accuracy: 0.4667 - val_loss: 19.4544
# Epoch 180/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9666 - loss: 0.1069 - val_accuracy: 0.1833 - val_loss: 42.3110
# Epoch 181/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9714 - loss: 0.0691 - val_accuracy: 0.5333 - val_loss: 6.3274
# Epoch 182/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9867 - loss: 0.0399 - val_accuracy: 0.3500 - val_loss: 20.0136
# Epoch 183/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9962 - loss: 0.0193 - val_accuracy: 0.5500 - val_loss: 5.3312
# Epoch 184/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0042 - val_accuracy: 0.5500 - val_loss: 5.2812
# Epoch 185/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9962 - loss: 0.0103 - val_accuracy: 0.7000 - val_loss: 3.4802
# Epoch 186/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9981 - loss: 0.0054 - val_accuracy: 0.7333 - val_loss: 3.9243
# Epoch 187/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9971 - loss: 0.0045 - val_accuracy: 0.7833 - val_loss: 1.2915
# Epoch 188/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9952 - loss: 0.0120 - val_accuracy: 0.5000 - val_loss: 8.8348
# Epoch 189/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9981 - loss: 0.0051 - val_accuracy: 0.6333 - val_loss: 5.0300
# Epoch 190/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.6667 - val_loss: 2.4794
# Epoch 191/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0046 - val_accuracy: 0.9167 - val_loss: 0.5493
# Epoch 192/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0027 - val_accuracy: 0.8500 - val_loss: 0.9786
# Epoch 193/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9867 - loss: 0.0704 - val_accuracy: 0.5167 - val_loss: 5.7814
# Epoch 194/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9695 - loss: 0.0910 - val_accuracy: 0.4500 - val_loss: 8.3658
# Epoch 195/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9838 - loss: 0.0583 - val_accuracy: 0.2500 - val_loss: 31.4767
# Epoch 196/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.9876 - loss: 0.0318 - val_accuracy: 0.6833 - val_loss: 5.7495
# Epoch 197/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9952 - loss: 0.0195 - val_accuracy: 0.2833 - val_loss: 20.8555
# Epoch 198/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9933 - loss: 0.0170 - val_accuracy: 0.5333 - val_loss: 8.9466
# Epoch 199/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9924 - loss: 0.0178 - val_accuracy: 0.4833 - val_loss: 9.4059
# Epoch 200/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9924 - loss: 0.0184 - val_accuracy: 0.4000 - val_loss: 11.8218
# Epoch 201/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9924 - loss: 0.0219 - val_accuracy: 0.2167 - val_loss: 68.0906
# Epoch 202/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9952 - loss: 0.0115 - val_accuracy: 0.5333 - val_loss: 14.1920
# Epoch 203/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9971 - loss: 0.0173 - val_accuracy: 0.6833 - val_loss: 3.1851
# Epoch 204/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9933 - loss: 0.0265 - val_accuracy: 0.5833 - val_loss: 7.0125
# Epoch 205/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9876 - loss: 0.0358 - val_accuracy: 0.6667 - val_loss: 1.5738
# Epoch 206/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9914 - loss: 0.0251 - val_accuracy: 0.6000 - val_loss: 5.0850
# Epoch 207/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9943 - loss: 0.0242 - val_accuracy: 0.5000 - val_loss: 6.7290
# Epoch 208/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9971 - loss: 0.0094 - val_accuracy: 0.7667 - val_loss: 1.4439
# Epoch 209/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0085 - val_accuracy: 0.6500 - val_loss: 4.2968
# Epoch 210/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9962 - loss: 0.0075 - val_accuracy: 0.7333 - val_loss: 1.8946
# Epoch 211/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9933 - loss: 0.0235 - val_accuracy: 0.8500 - val_loss: 1.0220
# Epoch 212/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9876 - loss: 0.0402 - val_accuracy: 0.8167 - val_loss: 1.0453
# Epoch 213/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9847 - loss: 0.0520 - val_accuracy: 0.4667 - val_loss: 15.4510
# Epoch 214/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9905 - loss: 0.0240 - val_accuracy: 0.4667 - val_loss: 13.8999
# Epoch 215/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9952 - loss: 0.0136 - val_accuracy: 0.6000 - val_loss: 9.4712
# Epoch 216/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0101 - val_accuracy: 0.4667 - val_loss: 6.5161
# Epoch 217/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9952 - loss: 0.0176 - val_accuracy: 0.7667 - val_loss: 1.7759
# Epoch 218/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9971 - loss: 0.0049 - val_accuracy: 0.3167 - val_loss: 11.5235
# Epoch 219/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 0.5333 - val_loss: 8.0021
# Epoch 220/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9981 - loss: 0.0045 - val_accuracy: 0.3667 - val_loss: 34.5241
# Epoch 221/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9876 - loss: 0.0796 - val_accuracy: 0.5000 - val_loss: 15.0720
# Epoch 222/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9685 - loss: 0.0939 - val_accuracy: 0.6000 - val_loss: 7.0073
# Epoch 223/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9886 - loss: 0.0374 - val_accuracy: 0.7333 - val_loss: 4.1454
# Epoch 224/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9952 - loss: 0.0108 - val_accuracy: 0.6333 - val_loss: 2.8210
# Epoch 225/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.7500 - val_loss: 1.0864
# Epoch 226/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0031 - val_accuracy: 0.8167 - val_loss: 0.9996
# Epoch 227/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0014 - val_accuracy: 0.4833 - val_loss: 8.5822
# Epoch 228/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9952 - loss: 0.0091 - val_accuracy: 0.5667 - val_loss: 4.0645
# Epoch 229/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9933 - loss: 0.0203 - val_accuracy: 0.5333 - val_loss: 4.7508
# Epoch 230/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0091 - val_accuracy: 0.6000 - val_loss: 2.7866
# Epoch 231/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9981 - loss: 0.0049 - val_accuracy: 0.7833 - val_loss: 0.8865
# Epoch 232/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0019 - val_accuracy: 0.8000 - val_loss: 1.2046
# Epoch 233/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8167 - val_loss: 1.2315
# Epoch 234/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0013 - val_accuracy: 0.7833 - val_loss: 1.9672
# Epoch 235/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9971 - loss: 0.0100 - val_accuracy: 0.4000 - val_loss: 11.4976
# Epoch 236/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9981 - loss: 0.0055 - val_accuracy: 0.5167 - val_loss: 10.0110
# Epoch 237/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.4167 - val_loss: 10.4711
# Epoch 238/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9971 - loss: 0.0120 - val_accuracy: 0.6833 - val_loss: 1.2820
# Epoch 239/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9924 - loss: 0.0296 - val_accuracy: 0.6167 - val_loss: 4.7031
# Epoch 240/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0055 - val_accuracy: 0.6333 - val_loss: 5.4852
# Epoch 241/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9943 - loss: 0.0232 - val_accuracy: 0.7667 - val_loss: 1.1734
# Epoch 242/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9924 - loss: 0.0161 - val_accuracy: 0.3667 - val_loss: 11.4365
# Epoch 243/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9971 - loss: 0.0068 - val_accuracy: 0.5000 - val_loss: 12.0338
# Epoch 244/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9971 - loss: 0.0060 - val_accuracy: 0.8000 - val_loss: 0.8342
# Epoch 245/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0028 - val_accuracy: 0.8833 - val_loss: 0.5532
# Epoch 246/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0032 - val_accuracy: 0.7167 - val_loss: 2.5116
# Epoch 247/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9895 - loss: 0.0564 - val_accuracy: 0.6833 - val_loss: 2.2335
# Epoch 248/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9771 - loss: 0.0514 - val_accuracy: 0.3667 - val_loss: 21.4375
# Epoch 249/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9828 - loss: 0.0503 - val_accuracy: 0.3667 - val_loss: 11.2916
# Epoch 250/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9952 - loss: 0.0140 - val_accuracy: 0.6333 - val_loss: 3.9626
# Epoch 251/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9962 - loss: 0.0082 - val_accuracy: 0.6167 - val_loss: 3.2668
# Epoch 252/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0022 - val_accuracy: 0.3333 - val_loss: 23.3667
# Epoch 253/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0030 - val_accuracy: 0.7000 - val_loss: 1.5925
# Epoch 254/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 2.7981e-04 - val_accuracy: 0.8667 - val_loss: 0.9488
# Epoch 255/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 3.3069e-04 - val_accuracy: 0.8667 - val_loss: 0.8714
# Epoch 256/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 1.0000 - loss: 4.6949e-04 - val_accuracy: 0.7667 - val_loss: 1.5906
# Epoch 257/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 4.1853e-04 - val_accuracy: 0.9000 - val_loss: 0.4344
# Epoch 258/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 1.4320e-04 - val_accuracy: 0.9000 - val_loss: 0.4166
# Epoch 259/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.7000 - val_loss: 2.3629
# Epoch 260/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 2.1638e-04 - val_accuracy: 0.7833 - val_loss: 1.6587
# Epoch 261/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 2.1104e-04 - val_accuracy: 0.8000 - val_loss: 1.3732
# Epoch 262/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 1.0201e-04 - val_accuracy: 0.8667 - val_loss: 1.0254
# Epoch 263/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 1.1325e-04 - val_accuracy: 0.8833 - val_loss: 0.9965
# Epoch 264/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 1.6668e-04 - val_accuracy: 0.9000 - val_loss: 0.5504
# Epoch 265/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 5.5888e-05 - val_accuracy: 0.9000 - val_loss: 0.4585
# Epoch 266/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 5.6696e-04 - val_accuracy: 0.5500 - val_loss: 4.4675
# Epoch 267/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0018 - val_accuracy: 0.7667 - val_loss: 1.7705
# Epoch 268/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 4.9440e-04 - val_accuracy: 0.8000 - val_loss: 1.5043
# Epoch 269/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 1.5974e-04 - val_accuracy: 0.8333 - val_loss: 1.1928
# Epoch 270/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 4.8935e-05 - val_accuracy: 0.8500 - val_loss: 1.0099
# Epoch 271/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9981 - loss: 0.0068 - val_accuracy: 0.8333 - val_loss: 1.1569
# Epoch 272/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 9.1701e-04 - val_accuracy: 0.4333 - val_loss: 9.5726
# Epoch 273/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 8.0650e-04 - val_accuracy: 0.6000 - val_loss: 4.5130
# Epoch 274/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 3.9485e-04 - val_accuracy: 0.8333 - val_loss: 1.8847
# Epoch 275/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 9.9548e-05 - val_accuracy: 0.8500 - val_loss: 1.1563
# Epoch 276/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0014 - val_accuracy: 0.5500 - val_loss: 8.7034
# Epoch 277/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0035 - val_accuracy: 0.3333 - val_loss: 19.8859
# Epoch 278/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9962 - loss: 0.0180 - val_accuracy: 0.5333 - val_loss: 5.8621
# Epoch 279/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9619 - loss: 0.1479 - val_accuracy: 0.2333 - val_loss: 90.0770
# Epoch 280/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9695 - loss: 0.0986 - val_accuracy: 0.4167 - val_loss: 16.0744
# Epoch 281/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9905 - loss: 0.0367 - val_accuracy: 0.6167 - val_loss: 3.4101
# Epoch 282/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9933 - loss: 0.0236 - val_accuracy: 0.4833 - val_loss: 19.6782
# Epoch 283/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.5833 - val_loss: 7.2283
# Epoch 284/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8000 - val_loss: 2.6429
# Epoch 285/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.4833 - val_loss: 7.2406
# Epoch 286/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8167 - val_loss: 1.4562
# Epoch 287/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 9.0601e-04 - val_accuracy: 0.8000 - val_loss: 2.3222
# Epoch 288/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 6.5819e-04 - val_accuracy: 0.6500 - val_loss: 3.4531
# Epoch 289/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 3.9256e-04 - val_accuracy: 0.6833 - val_loss: 2.5719
# Epoch 290/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 2.8512e-04 - val_accuracy: 0.7667 - val_loss: 1.8833
# Epoch 291/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9933 - loss: 0.0167 - val_accuracy: 0.7833 - val_loss: 1.2081
# Epoch 292/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9857 - loss: 0.0416 - val_accuracy: 0.2667 - val_loss: 10.1803
# Epoch 293/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9886 - loss: 0.0378 - val_accuracy: 0.5667 - val_loss: 3.1893
# Epoch 294/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9914 - loss: 0.0307 - val_accuracy: 0.6833 - val_loss: 2.6209
# Epoch 295/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0089 - val_accuracy: 0.8167 - val_loss: 1.1878
# Epoch 296/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0040 - val_accuracy: 0.8667 - val_loss: 0.6601
# Epoch 297/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 8.3670e-04 - val_accuracy: 0.8500 - val_loss: 0.7763
# Epoch 298/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0018 - val_accuracy: 0.7500 - val_loss: 2.1435
# Epoch 299/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.6667 - val_loss: 3.2519
# Epoch 300/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8000 - val_loss: 0.8377
# Epoch 301/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0021 - val_accuracy: 0.5833 - val_loss: 3.9639
# Epoch 302/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0023 - val_accuracy: 0.6500 - val_loss: 3.5814
# Epoch 303/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 3.6218e-04 - val_accuracy: 0.7167 - val_loss: 1.9734
# Epoch 304/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0014 - val_accuracy: 0.7833 - val_loss: 1.3813
# Epoch 305/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 6.3634e-04 - val_accuracy: 0.8500 - val_loss: 0.8541
# Epoch 306/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8833 - val_loss: 0.7281
# Epoch 307/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 7.7235e-04 - val_accuracy: 0.9333 - val_loss: 0.3723
# Epoch 308/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 5.6828e-04 - val_accuracy: 0.8167 - val_loss: 1.1894
# Epoch 309/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 2.3000e-04 - val_accuracy: 0.9000 - val_loss: 0.4305
# Epoch 310/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 1.3237e-04 - val_accuracy: 0.9333 - val_loss: 0.3696
# Epoch 311/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 1.8046e-04 - val_accuracy: 0.9000 - val_loss: 0.4081
# Epoch 312/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9962 - loss: 0.0123 - val_accuracy: 0.5833 - val_loss: 5.5555
# Epoch 313/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9914 - loss: 0.0309 - val_accuracy: 0.3833 - val_loss: 22.7419
# Epoch 314/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9857 - loss: 0.0534 - val_accuracy: 0.3500 - val_loss: 29.9341
# Epoch 315/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9466 - loss: 0.1849 - val_accuracy: 0.1833 - val_loss: 74.3454
# Epoch 316/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9790 - loss: 0.0783 - val_accuracy: 0.2500 - val_loss: 50.7551
# Epoch 317/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9838 - loss: 0.0449 - val_accuracy: 0.1833 - val_loss: 35.7377
# Epoch 318/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9952 - loss: 0.0142 - val_accuracy: 0.3167 - val_loss: 27.1216
# Epoch 319/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0060 - val_accuracy: 0.6333 - val_loss: 3.3478
# Epoch 320/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.6833 - val_loss: 2.3810
# Epoch 321/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 4.2749e-04 - val_accuracy: 0.7500 - val_loss: 1.2666
# Epoch 322/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0036 - val_accuracy: 0.8500 - val_loss: 0.9968
# Epoch 323/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9971 - loss: 0.0055 - val_accuracy: 0.6000 - val_loss: 3.3762
# Epoch 324/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0051 - val_accuracy: 0.3000 - val_loss: 21.5023
# Epoch 325/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9895 - loss: 0.0316 - val_accuracy: 0.7333 - val_loss: 2.0567
# Epoch 326/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9962 - loss: 0.0213 - val_accuracy: 0.5333 - val_loss: 4.3204
# Epoch 327/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9981 - loss: 0.0051 - val_accuracy: 0.7333 - val_loss: 2.0615
# Epoch 328/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.7833 - val_loss: 1.1312
# Epoch 329/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0033 - val_accuracy: 0.7667 - val_loss: 2.6571
# Epoch 330/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9990 - loss: 0.0024 - val_accuracy: 0.7333 - val_loss: 1.5416
# Epoch 331/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0043 - val_accuracy: 0.3833 - val_loss: 10.2327
# Epoch 332/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9952 - loss: 0.0151 - val_accuracy: 0.7833 - val_loss: 1.0388
# Epoch 333/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9962 - loss: 0.0069 - val_accuracy: 0.6667 - val_loss: 1.8287
# Epoch 334/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.7333 - val_loss: 2.2562
# Epoch 335/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 4.4260e-04 - val_accuracy: 0.8167 - val_loss: 1.8520
# Epoch 336/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 7.3443e-04 - val_accuracy: 0.9000 - val_loss: 0.4452
# Epoch 337/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 9.1585e-04 - val_accuracy: 0.7167 - val_loss: 1.9137
# Epoch 338/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 8.7713e-04 - val_accuracy: 0.8167 - val_loss: 0.8138
# Epoch 339/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 6.3545e-04 - val_accuracy: 0.9000 - val_loss: 0.2703
# Epoch 340/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 2.5312e-04 - val_accuracy: 0.9000 - val_loss: 0.3797
# Epoch 341/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0022 - val_accuracy: 0.6667 - val_loss: 2.3345
# Epoch 342/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 1.0000 - loss: 1.4137e-04 - val_accuracy: 0.8333 - val_loss: 1.1256
# Epoch 343/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 1.6691e-04 - val_accuracy: 0.8833 - val_loss: 0.9438
# Epoch 344/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 1.0000 - loss: 9.8726e-05 - val_accuracy: 0.8667 - val_loss: 0.7818
# Epoch 345/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 1.0000 - loss: 6.0592e-05 - val_accuracy: 0.8667 - val_loss: 0.7956
# Epoch 346/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 1.6937e-04 - val_accuracy: 0.8667 - val_loss: 0.9161
# Epoch 347/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 9.1961e-05 - val_accuracy: 0.8167 - val_loss: 1.0756
# Epoch 348/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 2.5190e-04 - val_accuracy: 0.9000 - val_loss: 0.5877
# Epoch 349/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 2.7320e-04 - val_accuracy: 0.8833 - val_loss: 0.3564
# Epoch 350/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 1.5126e-04 - val_accuracy: 0.9167 - val_loss: 0.3002
# Epoch 351/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 7.0448e-04 - val_accuracy: 0.8500 - val_loss: 1.4603
# Epoch 352/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9895 - loss: 0.0424 - val_accuracy: 0.3500 - val_loss: 26.8328
# Epoch 353/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9819 - loss: 0.0691 - val_accuracy: 0.3667 - val_loss: 26.6087
# Epoch 354/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9762 - loss: 0.0692 - val_accuracy: 0.6333 - val_loss: 3.6161
# Epoch 355/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9971 - loss: 0.0100 - val_accuracy: 0.4167 - val_loss: 13.3542
# Epoch 356/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9981 - loss: 0.0054 - val_accuracy: 0.6833 - val_loss: 2.5811
# Epoch 357/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0043 - val_accuracy: 0.7333 - val_loss: 4.2908
# Epoch 358/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9962 - loss: 0.0076 - val_accuracy: 0.8000 - val_loss: 1.4381
# Epoch 359/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9847 - loss: 0.0481 - val_accuracy: 0.3000 - val_loss: 16.8651
# Epoch 360/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9895 - loss: 0.0284 - val_accuracy: 0.6833 - val_loss: 1.6723
# Epoch 361/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9867 - loss: 0.0462 - val_accuracy: 0.8167 - val_loss: 0.5454
# Epoch 362/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9943 - loss: 0.0181 - val_accuracy: 0.8667 - val_loss: 0.8687
# Epoch 363/500
# ...
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0049 - val_accuracy: 0.5667 - val_loss: 7.2206
# Epoch 382/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0035 - val_accuracy: 0.4000 - val_loss: 13.3154
# Epoch 383/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9990 - loss: 0.0037 - val_accuracy: 0.2167 - val_loss: 36.9271
# Epoch 384/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9943 - loss: 0.0153 - val_accuracy: 0.2333 - val_loss: 40.6420
# Epoch 385/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9895 - loss: 0.0234 - val_accuracy: 0.2667 - val_loss: 38.3296
# Epoch 386/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9895 - loss: 0.0288 - val_accuracy: 0.5167 - val_loss: 7.2881
# Epoch 387/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9962 - loss: 0.0104 - val_accuracy: 0.2167 - val_loss: 20.3082
# Epoch 388/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.4333 - val_loss: 11.0772
# Epoch 389/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 5.0614e-04 - val_accuracy: 0.3667 - val_loss: 6.4134
# Epoch 390/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8333 - val_loss: 0.6484
# Epoch 391/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0021 - val_accuracy: 0.7667 - val_loss: 1.7903
# Epoch 392/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9943 - loss: 0.0114 - val_accuracy: 0.5500 - val_loss: 4.7974
# Epoch 393/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9962 - loss: 0.0108 - val_accuracy: 0.1833 - val_loss: 47.5213
# Epoch 394/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0027 - val_accuracy: 0.3000 - val_loss: 23.9491
# Epoch 395/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 6.4857e-04 - val_accuracy: 0.4500 - val_loss: 10.9262
# Epoch 396/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 1.5903e-04 - val_accuracy: 0.6833 - val_loss: 3.5830
# Epoch 397/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 3.6724e-04 - val_accuracy: 0.9000 - val_loss: 0.5452
# Epoch 398/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 5.8891e-04 - val_accuracy: 0.9000 - val_loss: 0.5043
# Epoch 399/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 3.6249e-04 - val_accuracy: 0.8833 - val_loss: 0.5707
# Epoch 400/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 1.4241e-04 - val_accuracy: 0.8833 - val_loss: 0.6878
# Epoch 401/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 5.6436e-04 - val_accuracy: 0.8000 - val_loss: 1.2343
# Epoch 402/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 3.4058e-04 - val_accuracy: 0.7500 - val_loss: 2.1070
# Epoch 403/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 6.6797e-04 - val_accuracy: 0.6167 - val_loss: 3.5118
# Epoch 404/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 6.1581e-04 - val_accuracy: 0.8500 - val_loss: 1.1828
# Epoch 405/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 4.3056e-04 - val_accuracy: 0.8833 - val_loss: 0.4927
# Epoch 406/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 5.3662e-05 - val_accuracy: 0.9000 - val_loss: 0.2981
# Epoch 407/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 1.4764e-04 - val_accuracy: 0.9000 - val_loss: 0.3115
# Epoch 408/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0019 - val_accuracy: 0.9000 - val_loss: 0.5276
# Epoch 409/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0017 - val_accuracy: 0.7167 - val_loss: 2.5187
# Epoch 410/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.6500 - val_loss: 3.6423
# Epoch 411/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9905 - loss: 0.0471 - val_accuracy: 0.3500 - val_loss: 19.9378
# Epoch 412/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9867 - loss: 0.0709 - val_accuracy: 0.6667 - val_loss: 3.8285
# Epoch 413/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9933 - loss: 0.0195 - val_accuracy: 0.7500 - val_loss: 0.9242
# Epoch 414/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9828 - loss: 0.0433 - val_accuracy: 0.4500 - val_loss: 9.6034
# Epoch 415/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9933 - loss: 0.0217 - val_accuracy: 0.5000 - val_loss: 12.1007
# Epoch 416/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9971 - loss: 0.0077 - val_accuracy: 0.5500 - val_loss: 9.4027
# Epoch 417/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9943 - loss: 0.0146 - val_accuracy: 0.8500 - val_loss: 1.2328
# Epoch 418/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9943 - loss: 0.0196 - val_accuracy: 0.6500 - val_loss: 4.0995
# Epoch 419/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0059 - val_accuracy: 0.6167 - val_loss: 3.4522
# Epoch 420/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 6.0563e-04 - val_accuracy: 0.5167 - val_loss: 5.6222
# Epoch 421/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9981 - loss: 0.0162 - val_accuracy: 0.5167 - val_loss: 7.0040
# Epoch 422/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9838 - loss: 0.0573 - val_accuracy: 0.4833 - val_loss: 10.0152
# Epoch 423/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9952 - loss: 0.0144 - val_accuracy: 0.4833 - val_loss: 10.3304
# Epoch 424/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.6833 - val_loss: 4.0878
# Epoch 425/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0027 - val_accuracy: 0.8167 - val_loss: 1.0913
# Epoch 426/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 7.9608e-04 - val_accuracy: 0.8167 - val_loss: 0.8345
# Epoch 427/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 4.1628e-04 - val_accuracy: 0.8667 - val_loss: 0.5703
# Epoch 428/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0025 - val_accuracy: 0.7500 - val_loss: 3.5368
# Epoch 429/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.7500 - val_loss: 1.4621
# Epoch 430/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 1.2694e-04 - val_accuracy: 0.7500 - val_loss: 1.8967
# Epoch 431/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 3.3812e-04 - val_accuracy: 0.7833 - val_loss: 1.3816
# Epoch 432/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9943 - loss: 0.0089 - val_accuracy: 0.5167 - val_loss: 4.8312
# Epoch 433/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0096 - val_accuracy: 0.1833 - val_loss: 74.8223
# Epoch 434/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9971 - loss: 0.0064 - val_accuracy: 0.4333 - val_loss: 21.3649
# Epoch 435/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9962 - loss: 0.0087 - val_accuracy: 0.5500 - val_loss: 3.3232
# Epoch 436/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9962 - loss: 0.0141 - val_accuracy: 0.3833 - val_loss: 9.2837
# Epoch 437/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9924 - loss: 0.0206 - val_accuracy: 0.6500 - val_loss: 3.2538
# Epoch 438/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9952 - loss: 0.0192 - val_accuracy: 0.2667 - val_loss: 16.9163
# Epoch 439/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9943 - loss: 0.0128 - val_accuracy: 0.4833 - val_loss: 12.5612
# Epoch 440/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9905 - loss: 0.0363 - val_accuracy: 0.7833 - val_loss: 1.3044
# Epoch 441/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9924 - loss: 0.0238 - val_accuracy: 0.3500 - val_loss: 7.2772
# Epoch 442/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0146 - val_accuracy: 0.3833 - val_loss: 19.8666
# Epoch 443/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9952 - loss: 0.0136 - val_accuracy: 0.5833 - val_loss: 4.0459
# Epoch 444/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9924 - loss: 0.0358 - val_accuracy: 0.4000 - val_loss: 16.1234
# Epoch 445/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9971 - loss: 0.0080 - val_accuracy: 0.6500 - val_loss: 5.7905
# Epoch 446/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.7500 - val_loss: 1.5828
# Epoch 447/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 4.4957e-04 - val_accuracy: 0.8167 - val_loss: 1.0485
# Epoch 448/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 2.6659e-04 - val_accuracy: 0.8333 - val_loss: 0.4914
# Epoch 449/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8833 - val_loss: 0.2625
# Epoch 450/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 1.8722e-04 - val_accuracy: 0.9000 - val_loss: 0.2395
# Epoch 451/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 1.0000 - loss: 1.3825e-04 - val_accuracy: 0.9000 - val_loss: 0.2550
# Epoch 452/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 1.0824e-04 - val_accuracy: 0.9000 - val_loss: 0.2568
# Epoch 453/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 8.0739e-05 - val_accuracy: 0.9000 - val_loss: 0.2525
# Epoch 454/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 1.5064e-04 - val_accuracy: 0.9167 - val_loss: 0.3149
# Epoch 455/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 2.9205e-04 - val_accuracy: 0.9167 - val_loss: 0.4326
# Epoch 456/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 2.2365e-04 - val_accuracy: 0.9167 - val_loss: 0.3653
# Epoch 457/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 4.0668e-05 - val_accuracy: 0.9000 - val_loss: 0.2764
# Epoch 458/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 1.7858e-04 - val_accuracy: 0.9000 - val_loss: 0.2578
# Epoch 459/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0044 - val_accuracy: 0.8167 - val_loss: 0.9745
# Epoch 460/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9952 - loss: 0.0144 - val_accuracy: 0.5000 - val_loss: 14.3297
# Epoch 461/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.9981 - loss: 0.0059 - val_accuracy: 0.5667 - val_loss: 10.9566
# Epoch 462/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0056 - val_accuracy: 0.7500 - val_loss: 1.8040
# Epoch 463/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8333 - val_loss: 0.6336
# Epoch 464/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 5.4540e-04 - val_accuracy: 0.8833 - val_loss: 0.4639
# Epoch 465/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 4.2482e-04 - val_accuracy: 0.9167 - val_loss: 0.3834
# Epoch 466/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 198ms/step - accuracy: 1.0000 - loss: 3.4892e-04 - val_accuracy: 0.9167 - val_loss: 0.3511
# Epoch 467/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 1.0000 - loss: 1.6181e-04 - val_accuracy: 0.9333 - val_loss: 0.3385
# Epoch 468/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 1.4820e-04 - val_accuracy: 0.9333 - val_loss: 0.3253
# Epoch 469/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 9.9079e-04 - val_accuracy: 0.6167 - val_loss: 3.0883
# Epoch 470/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 2.8403e-04 - val_accuracy: 0.7667 - val_loss: 1.8868
# Epoch 471/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8500 - val_loss: 2.1654
# Epoch 472/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9924 - loss: 0.0156 - val_accuracy: 0.7667 - val_loss: 2.4537
# Epoch 473/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9857 - loss: 0.0679 - val_accuracy: 0.1833 - val_loss: 94.1488
# Epoch 474/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9695 - loss: 0.1179 - val_accuracy: 0.2333 - val_loss: 35.7541
# Epoch 475/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9867 - loss: 0.0331 - val_accuracy: 0.2833 - val_loss: 12.0483
# Epoch 476/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.4833 - val_loss: 3.6153
# Epoch 477/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9981 - loss: 0.0058 - val_accuracy: 0.5667 - val_loss: 3.4544
# Epoch 478/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.8167 - val_loss: 1.0237
# Epoch 479/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9971 - loss: 0.0058 - val_accuracy: 0.6333 - val_loss: 6.9397
# Epoch 480/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9971 - loss: 0.0082 - val_accuracy: 0.5000 - val_loss: 10.7412
# Epoch 481/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9971 - loss: 0.0072 - val_accuracy: 0.3833 - val_loss: 10.2486
# Epoch 482/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9990 - loss: 0.0031 - val_accuracy: 0.8333 - val_loss: 0.9573
# Epoch 483/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9990 - loss: 0.0023 - val_accuracy: 0.6000 - val_loss: 4.4182
# Epoch 484/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.7833 - val_loss: 1.2944
# Epoch 485/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 4.7243e-04 - val_accuracy: 0.8333 - val_loss: 0.7032
# Epoch 486/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 1.1034e-04 - val_accuracy: 0.9000 - val_loss: 0.5888
# Epoch 487/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 1.0000 - loss: 1.4599e-04 - val_accuracy: 0.8667 - val_loss: 0.5442
# Epoch 488/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 1.0000 - loss: 1.3190e-04 - val_accuracy: 0.8833 - val_loss: 0.5168
# Epoch 489/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9952 - loss: 0.0103 - val_accuracy: 0.3667 - val_loss: 16.8388
# Epoch 490/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.9971 - loss: 0.0147 - val_accuracy: 0.3167 - val_loss: 18.4800
# Epoch 491/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9828 - loss: 0.0630 - val_accuracy: 0.4000 - val_loss: 28.5059
# Epoch 492/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9571 - loss: 0.1264 - val_accuracy: 0.3500 - val_loss: 31.4291
# Epoch 493/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9857 - loss: 0.0383 - val_accuracy: 0.7667 - val_loss: 2.2885
# Epoch 494/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9857 - loss: 0.0417 - val_accuracy: 0.5500 - val_loss: 6.4646
# Epoch 495/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.9838 - loss: 0.0445 - val_accuracy: 0.4000 - val_loss: 9.7404
# Epoch 496/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.9790 - loss: 0.1354 - val_accuracy: 0.5333 - val_loss: 6.5304
# Epoch 497/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.6206 - loss: 1.2441 - val_accuracy: 0.2833 - val_loss: 3.1878
# Epoch 498/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.7760 - loss: 0.5851 - val_accuracy: 0.3167 - val_loss: 3.2443
# Epoch 499/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.8570 - loss: 0.3745 - val_accuracy: 0.4167 - val_loss: 2.7028
# Epoch 500/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 188ms/step - accuracy: 0.8999 - loss: 0.2688 - val_accuracy: 0.4167 - val_loss: 3.8228
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9333 - loss: 0.3494
# Validation accuracy: 93.33%

# %% [markdown]
# ## Results and TFLite conversion
#
# With about one million parameters, getting to ~85% top-1 accuracy on 256x256 resolution is
# a strong result. This MobileViT mobile is fully compatible with TensorFlow Lite (TFLite)
# and can be converted with the following code:

# %%
loss, accuracy = mobilevit_xxs.evaluate(test_dataset)
print('Test accuracy :', accuracy)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - accuracy: 0.7800 - loss: 0.8117
# Test accuracy : 0.7799999713897705

# %%
# !pip install scikit-learn

from sklearn.metrics import confusion_matrix, classification_report, precision_recall_fscore_support, average_precision_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

predictions = mobilevit_xxs.predict(test_dataset)

# Extract true labels from the test dataset.
y_true = []
for images, labels in test_dataset:  # Iterate through the dataset
    y_true.extend(labels.numpy())

# Assuming 'predictions' contains probabilities, convert them to class predictions
y_pred = predictions.argmax(axis=1)

print(classification_report(y_true, y_pred))
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step
#               precision    recall  f1-score   support
#
#            0       0.19      0.26      0.22        19
#            1       0.19      0.16      0.17        19
#            2       0.22      0.30      0.26        20
#            3       0.14      0.09      0.11        22
#            4       0.31      0.25      0.28        20
#
#     accuracy                           0.21       100
#    macro avg       0.21      0.21      0.21       100
# weighted avg       0.21      0.21      0.20       100

# %%
import os
import time
import numpy as np
import tensorflow as tf
from tensorflow import keras

# Import the preprocess_input function
from keras.applications.imagenet_utils import preprocess_input

# Lista para armazenar tempos de inferência
tempos_de_inferencia = []

# Caminho das imagens para inferência
caminho_dados = "/content/drive/MyDrive/TypeCoffee.v28i.folder/train/Mole/"
imagens = [os.path.join(caminho_dados, nome) for nome in os.listdir(caminho_dados)]

# Make sure you've defined or loaded 'model' before this loop
model = mobilevit_xxs

for imagem in imagens:
    inicio = time.time()  # Marca o início do processo
   # Load the image and preprocess it
    img = tf.keras.utils.load_img(imagem, target_size=(256, 256))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)
    img_array = preprocess_input(img_array)  # Apply preprocessing if necessary

    predictions = model.predict(img_array)  # Make predictions

    # You can process 'predictions' here, such as getting the class with highest probability
    predicted_class_index = np.argmax(predictions[0])

    fim = time.time()

    # Calcula o tempo de inferência
    tempos_de_inferencia.append(fim - inicio)

# Cálculo da média dos tempos
media_tempo_inferencia = np.mean(tempos_de_inferencia)

print(f"Média do tempo de inferência: {media_tempo_inferencia:.4f} segundos")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Média do tempo de inferência: 0.9787 segundos

# %%
y_true = []
y_pred = []
for images, labels in test_dataset:
  predictions = mobilevit_xxs.predict(images)
  predicted_labels = np.argmax(predictions, axis=1)
  y_true.extend(labels.numpy())
  y_pred.extend(predicted_labels)

precision, recall, f1_score, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1_score)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# Precision: 0.8149371693121694
# Recall: 0.78
# F1 Score: 0.7785771551914012

# %%
import torch
torch.save(mobilevit_xxs, 'meu_modelo_mobilevit.pt')

# %% [markdown]
# To learn more about different quantization recipes available in TFLite and running
# inference with TFLite models, check out
# [this official resource](https://www.tensorflow.org/lite/performance/post_training_quantization).
#
# You can use the trained model hosted on [Hugging Face Hub](https://huggingface.co/keras-io/mobile-vit-xxs)
# and try the demo on [Hugging Face Spaces](https://huggingface.co/spaces/keras-io/Flowers-Classification-MobileViT).
